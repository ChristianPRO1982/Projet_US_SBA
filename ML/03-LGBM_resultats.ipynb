# %% [markdown]
# ___
# ___
# ___
# # RESULTATS DE Light GBM
# ___
# ___
# ___

# %% [markdown]
#                 .''.      .        *''*    :_\/_:     .
#                :_\/_:   _\(/_  .:.*_\/_*   : /\ :  .'.:.'.
#            .''.: /\ :   ./)\   ':'* /\ * :  '..'.  -=:o:=-
#           :_\/_:'.:::.    ' *''*    * '.\'/.' _\(/_'.':'.'
#           : /\ : :::::     *_\/_*     -= o =-  /)\    '  *
#            '..'  ':::'     * /\ *     .'/.\'.   '
#                *            *..*         :
#
#
#                                         .''.
#             .''.      .        *''*    :_\/_:     .
#            :_\/_:   _\(/_  .:.*_\/_*   : /\ :  .'.:.'.
#        .''.: /\ :    /)\   ':'* /\ *  : '..'.  -=:o:=-
#       :_\/_:'.:::.  | ' *''*    * '.\'/.'_\(/_'.':'.'
#       : /\ : :::::  =  *_\/_*     -= o =- /)\    '  *
#        '..'  ':::' === * /\ *     .'/.\'.  ' ._____
#            *        |   *..*         :       |.   |' .---"|
#              *      |     _           .--'|  ||   | _|    |
#              *      |  .-'|       __  |   |  |    ||      |
#           .-----.   |  |' |  ||  |  | |   |  |    ||      |
#       ___'       ' /"\ |  '-."".    '-'   '-.'    '`      |
#      ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                             ~-~-~-~-~-~-~-~-~-~   /|
#                )      ~-~-~-~-~-~-~-~  /|~       /_|\
#              _-H-__  -~-~-~-~-~-~     /_|\    -~======-~
#      ~-\XXXXXXXXXX/~     ~-~-~-~     /__|_\ ~-~-~-~
#      ~-~-~-~-~-~    ~-~~-~-~-~-~    ========  ~-~-~-~

# %% [markdown]
# ___
#      LGBM execution time is:  0:01:14.446379
# ___
#               precision    recall  f1-score       support
# 0              0.867287  0.829877  0.848170   7859.000000
# 1              0.964079  0.972941  0.968490  36882.000000
# accuracy       0.947811  0.947811  0.947811      0.947811
# macro avg      0.915683  0.901409  0.908330  44741.000000
# weighted avg   0.947077  0.947811  0.947355  44741.000000
# ___
#                   F1 macro score: 0.9083
# ___
