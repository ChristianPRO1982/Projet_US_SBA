# %% [markdown]
# ___
# ___
# ___
# # PYCARET
# ___
# ___
# ___

# %%
from pycaret.classification import *
import pycaret

# %%
import pandas as pd

df = pd.read_csv('./data_set/SBAnational-EDA.csv')
# df = pd.read_csv('./data_set/SBAnational1000.csv')

df = df.drop(columns=['Unnamed: 0', 'ChgOffDate', 'DisbursementDate', 'DisbursementGross', 'BalanceGross', 'ChgOffPrinGr'], axis=1).reset_index(drop=True)
df = df.drop(columns=['CreateJob', 'RetainedJob'], axis=1).reset_index(drop=True)
df = df[['NAICS', 'ApprovalDate', 'ApprovalFY', 'Term', 'UrbanRural', 'GrAppv', 'SBA_Appv', 'MIS_Status']]

# Initialisation l'environnement PyCaret en spécifiant la colonne cible
session = setup(data=df, target='MIS_Status', normalize=True, train_size=0.7, data_split_stratify=True, fold=5, session_id=0)
df
# Out:
# <style type="text/css">
# #T_335dc_row10_col1, #T_335dc_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_335dc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_335dc_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_335dc_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_335dc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_335dc_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_335dc_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_335dc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_335dc_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_335dc_row1_col1" class="data row1 col1" >MIS_Status</td>
#     </tr>
#     <tr>
#       <th id="T_335dc_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
algo = models()
print(algo)
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# catboost              CatBoost Classifier
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# ...

# %%
top_models = compare_models(n_select=3, sort="Accuracy", include=['lr', 'knn', 'dt', 'ridge', 'rf', 'lightgbm', 'xgboost'])
print(top_models)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  15:35:45
# Status     . . . . . . . . . . . . . . . . . .           Fitting 5 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Classifier
# <style type="text/css">
# #T_ba3fa th {
#   text-align: left;
# }
# ...
